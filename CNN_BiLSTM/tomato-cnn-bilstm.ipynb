# %% [markdown]
# ### Import all the Dependencies

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### Import data into tensorflow dataset object

# %%
# Constants
IMAGE_SIZE = 224  # Replace with your desired image size
BATCH_SIZE = 32
DATASET_DIR = '/kaggle/input/tomatoleaf/Dataset3'  # Path to your dataset directory
CLASS_NAMES = os.listdir(DATASET_DIR)

# Prepare a list of all image paths and corresponding labels
image_paths = []
labels = []

for class_name in CLASS_NAMES:
    class_dir = os.path.join(DATASET_DIR, class_name)
    for img_name in os.listdir(class_dir):
        image_paths.append(os.path.join(class_dir, img_name))
        labels.append(class_name)

# Create a DataFrame
data = pd.DataFrame({'image_path': image_paths, 'label': labels})

# %%
# Split into train, validation, and test sets
train_data, test_data = train_test_split(data, test_size=0.1, stratify=data['label'], random_state=42)
train_data, val_data = train_test_split(train_data, test_size=0.125, stratify=train_data['label'], random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# Data Augmentation and Data Generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.1,
    height_shift_range=0.1, 
    shear_range=0.2, 
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
)

train_generator = train_datagen.flow_from_dataframe(
    train_data,
    x_col='image_path',
    y_col='label',
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = validation_datagen.flow_from_dataframe(
    val_data,
    x_col='image_path',
    y_col='label',
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_dataframe(
    test_data,
    x_col='image_path',
    y_col='label',
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False  # Important to maintain order for evaluation
)
# Out:
# Found 25618 validated image filenames belonging to 11 classes.
# Found 3660 validated image filenames belonging to 11 classes.
# Found 3254 validated image filenames belonging to 11 classes.

# %%
# Get class indices
class_indices = train_generator.class_indices

# Map class names to their image counts
class_counts_dict = train_data['label'].value_counts().to_dict()

# Create a list of counts in the order of train_generator.class_indices
ordered_counts = [(class_name, class_counts_dict.get(class_name, 0)) for class_name in class_indices.keys()]

# Convert to a DataFrame for better visualization
ordered_counts_df = pd.DataFrame(ordered_counts, columns=['Class Name', 'Image Count'])

# Print the ordered counts
print(ordered_counts_df)
# Out:
#                               Class Name  Image Count
# 0                         Bacterial_spot         2802
# 1                           Early_blight         2439
# 2                            Late_blight         3075
# 3                              Leaf_Mold         2751
# 4                     Septoria_leaf_spot         2857
# 5   Spider_mites Two-spotted_spider_mite         1718
# 6                            Target_Spot         1799
# 7          Tomato_Yellow_Leaf_Curl_Virus         1996
# 8                    Tomato_mosaic_virus         2155
# 9                                healthy         3037
# 10                        powdery_mildew          989

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights = dict(enumerate(class_weights))

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=0)
]

# %% [markdown]
# ## Building the Model

# %%
from tensorflow.keras.models import Model
from keras.layers import Flatten, Dense,TimeDistributed,Conv2D,MaxPooling2D,LSTM,Dropout,Reshape,Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2 

strategy=tf.distribute.MirroredStrategy()
with strategy.scope():
    
    model = Sequential()
    
    # CNN Feature Extraction (using TimeDistributed for sequences)
    model.add(Conv2D(32, (3, 3), activation='relu',padding='same', kernel_regularizer=l2(0.001), input_shape=(224, 224, 3))) #None for variable sequence length
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))
    
    model.add(Conv2D(64, (3, 3), activation='relu',padding='same',kernel_regularizer=l2(0.001)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3)) 

    # model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    # model.add(MaxPooling2D((2, 2)))
    # model.add(Dropout(0.3))
    
    model.add(Flatten())
    model.add(Reshape((1, -1)))
    # LSTM for Temporal Modeling
    model.add(Bidirectional(LSTM(64, return_sequences=True,dropout=0.3, recurrent_dropout=0.3))) # Keep return_sequences if you want to stack LSTMs
    model.add(Bidirectional(LSTM(32, return_sequences=False,dropout=0.3, recurrent_dropout=0.3)))
    
    # Classification
    # Dense Layers and Classification
    # model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.001)))
    # model.add(Dropout(0.3))  # Dropout in Dense layer
    model.add(Dense(11, activation='softmax'))

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy','Precision','Recall'])
print(model.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 224, 224, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 112, 112, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 200704)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 1, 200704)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 1, 128)              │     102,793,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 64)                  │          41,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 11)                  │           1,419 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 102,864,075 (392.40 MB)
#  Trainable params: 102,864,075 (392.40 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
history = model.fit(
    train_generator,
    batch_size=BATCH_SIZE ,
    # steps_per_epoch = steps_per_epoch,  # Total samples / batch_size
    validation_data=validation_generator,
    # validation_steps = validation_steps,
    epochs=30,
    callbacks = callbacks
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 539s 649ms/step - Precision: 0.0914 - Recall: 8.4442e-05 - accuracy: 0.1732 - loss: 2.3845 - val_Precision: 0.8302 - val_Recall: 0.0481 - val_accuracy: 0.2956 - val_loss: 1.9828 - learning_rate: 1.0000e-04
# Epoch 2/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 342s 423ms/step - Precision: 0.7892 - Recall: 0.1061 - accuracy: 0.4506 - loss: 1.6927 - val_Precision: 0.6207 - val_Recall: 0.2585 - val_accuracy: 0.4699 - val_loss: 1.6215 - learning_rate: 1.0000e-04
# Epoch 3/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 343s 425ms/step - Precision: 0.8184 - Recall: 0.3835 - accuracy: 0.6114 - loss: 1.2564 - val_Precision: 0.6790 - val_Recall: 0.4208 - val_accuracy: 0.5426 - val_loss: 1.4196 - learning_rate: 1.0000e-04
# Epoch 4/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 341s 422ms/step - Precision: 0.8221 - Recall: 0.5184 - accuracy: 0.6694 - loss: 1.0792 - val_Precision: 0.6667 - val_Recall: 0.4426 - val_accuracy: 0.5579 - val_loss: 1.3855 - learning_rate: 1.0000e-04
# Epoch 5/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 341s 422ms/step - Precision: 0.8325 - Recall: 0.5791 - accuracy: 0.6986 - loss: 0.9851 - val_Precision: 0.6494 - val_Recall: 0.4798 - val_accuracy: 0.5639 - val_loss: 1.3765 - learning_rate: 1.0000e-04
# Epoch 6/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 340s 421ms/step - Precision: 0.8488 - Recall: 0.6248 - accuracy: 0.7298 - loss: 0.9077 - val_Precision: 0.6659 - val_Recall: 0.4880 - val_accuracy: 0.5814 - val_loss: 1.3380 - learning_rate: 1.0000e-04
# Epoch 7/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 343s 425ms/step - Precision: 0.8593 - Recall: 0.6589 - accuracy: 0.7481 - loss: 0.8435 - val_Precision: 0.6994 - val_Recall: 0.5415 - val_accuracy: 0.6202 - val_loss: 1.2246 - learning_rate: 1.0000e-04
# Epoch 8/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 345s 427ms/step - Precision: 0.8737 - Recall: 0.6885 - accuracy: 0.7722 - loss: 0.7767 - val_Precision: 0.7378 - val_Recall: 0.5721 - val_accuracy: 0.6475 - val_loss: 1.1578 - learning_rate: 1.0000e-04
# Epoch 9/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 344s 426ms/step - Precision: 0.8730 - Recall: 0.7025 - accuracy: 0.7794 - loss: 0.7518 - val_Precision: 0.7273 - val_Recall: 0.5814 - val_accuracy: 0.6574 - val_loss: 1.1195 - learning_rate: 1.0000e-04
# Epoch 10/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 342s 423ms/step - Precision: 0.8797 - Recall: 0.7242 - accuracy: 0.7926 - loss: 0.7083 - val_Precision: 0.7616 - val_Recall: 0.6093 - val_accuracy: 0.6885 - val_loss: 1.0481 - learning_rate: 1.0000e-04
# Epoch 11/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 343s 425ms/step - Precision: 0.8823 - Recall: 0.7374 - accuracy: 0.8008 - loss: 0.6807 - val_Precision: 0.7592 - val_Recall: 0.6202 - val_accuracy: 0.6869 - val_loss: 1.0158 - learning_rate: 1.0000e-04
# Epoch 12/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 345s 427ms/step - Precision: 0.8852 - Recall: 0.7550 - accuracy: 0.8140 - loss: 0.6462 - val_Precision: 0.7386 - val_Recall: 0.6131 - val_accuracy: 0.6760 - val_loss: 1.0930 - learning_rate: 1.0000e-04
# Epoch 13/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 344s 426ms/step - Precision: 0.8915 - Recall: 0.7630 - accuracy: 0.8188 - loss: 0.6222 - val_Precision: 0.7940 - val_Recall: 0.6486 - val_accuracy: 0.7240 - val_loss: 0.9293 - learning_rate: 1.0000e-04
# Epoch 14/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 340s 422ms/step - Precision: 0.8997 - Recall: 0.7729 - accuracy: 0.8271 - loss: 0.5956 - val_Precision: 0.7955 - val_Recall: 0.6760 - val_accuracy: 0.7333 - val_loss: 0.8735 - learning_rate: 1.0000e-04
# Epoch 15/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 341s 422ms/step - Precision: 0.8966 - Recall: 0.7797 - accuracy: 0.8300 - loss: 0.5865 - val_Precision: 0.7346 - val_Recall: 0.6049 - val_accuracy: 0.6639 - val_loss: 1.1790 - learning_rate: 1.0000e-04
# Epoch 16/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 344s 426ms/step - Precision: 0.9086 - Recall: 0.7951 - accuracy: 0.8445 - loss: 0.5480 - val_Precision: 0.7710 - val_Recall: 0.6530 - val_accuracy: 0.7126 - val_loss: 1.0270 - learning_rate: 1.0000e-04
# Epoch 17/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 341s 422ms/step - Precision: 0.9103 - Recall: 0.8072 - accuracy: 0.8534 - loss: 0.5194 - val_Precision: 0.7865 - val_Recall: 0.6661 - val_accuracy: 0.7268 - val_loss: 0.9592 - learning_rate: 1.0000e-04
# Epoch 18/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 344s 426ms/step - Precision: 0.9098 - Recall: 0.8108 - accuracy: 0.8546 - loss: 0.5078 - val_Precision: 0.7926 - val_Recall: 0.6683 - val_accuracy: 0.7240 - val_loss: 0.9422 - learning_rate: 1.0000e-04
# Epoch 19/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 338s 419ms/step - Precision: 0.9121 - Recall: 0.8128 - accuracy: 0.8586 - loss: 0.4950 - val_Precision: 0.7320 - val_Recall: 0.6180 - val_accuracy: 0.6787 - val_loss: 1.1318 - learning_rate: 1.0000e-04
# Epoch 20/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 342s 423ms/step - Precision: 0.9261 - Recall: 0.8342 - accuracy: 0.8755 - loss: 0.4576 - val_Precision: 0.8290 - val_Recall: 0.7284 - val_accuracy: 0.7765 - val_loss: 0.7686 - learning_rate: 5.0000e-05
# Epoch 21/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 338s 419ms/step - Precision: 0.9243 - Recall: 0.8399 - accuracy: 0.8767 - loss: 0.4435 - val_Precision: 0.7904 - val_Recall: 0.6945 - val_accuracy: 0.7459 - val_loss: 0.9185 - learning_rate: 5.0000e-05
# Epoch 22/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 341s 423ms/step - Precision: 0.9239 - Recall: 0.8410 - accuracy: 0.8776 - loss: 0.4386 - val_Precision: 0.8005 - val_Recall: 0.7038 - val_accuracy: 0.7508 - val_loss: 0.8797 - learning_rate: 5.0000e-05
# Epoch 23/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 345s 427ms/step - Precision: 0.9252 - Recall: 0.8458 - accuracy: 0.8801 - loss: 0.4263 - val_Precision: 0.8268 - val_Recall: 0.7486 - val_accuracy: 0.7852 - val_loss: 0.7817 - learning_rate: 5.0000e-05
# Epoch 24/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 343s 425ms/step - Precision: 0.9291 - Recall: 0.8519 - accuracy: 0.8857 - loss: 0.4186 - val_Precision: 0.8221 - val_Recall: 0.7350 - val_accuracy: 0.7743 - val_loss: 0.7687 - learning_rate: 5.0000e-05
# Epoch 25/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 346s 428ms/step - Precision: 0.9276 - Recall: 0.8505 - accuracy: 0.8862 - loss: 0.4165 - val_Precision: 0.8000 - val_Recall: 0.7279 - val_accuracy: 0.7579 - val_loss: 0.9079 - learning_rate: 5.0000e-05
# Epoch 26/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 346s 428ms/step - Precision: 0.9311 - Recall: 0.8575 - accuracy: 0.8905 - loss: 0.4013 - val_Precision: 0.8053 - val_Recall: 0.7142 - val_accuracy: 0.7568 - val_loss: 0.8521 - learning_rate: 2.5000e-05
# Epoch 27/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 346s 428ms/step - Precision: 0.9394 - Recall: 0.8661 - accuracy: 0.8973 - loss: 0.3852 - val_Precision: 0.8285 - val_Recall: 0.7525 - val_accuracy: 0.7907 - val_loss: 0.7681 - learning_rate: 2.5000e-05
# Epoch 28/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 342s 424ms/step - Precision: 0.9344 - Recall: 0.8656 - accuracy: 0.8949 - loss: 0.3830 - val_Precision: 0.7899 - val_Recall: 0.7087 - val_accuracy: 0.7481 - val_loss: 0.8896 - learning_rate: 2.5000e-05
# Epoch 29/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 342s 423ms/step - Precision: 0.9370 - Recall: 0.8678 - accuracy: 0.8959 - loss: 0.3776 - val_Precision: 0.7928 - val_Recall: 0.7087 - val_accuracy: 0.7475 - val_loss: 0.9323 - learning_rate: 2.5000e-05
# Epoch 30/30
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 341s 422ms/step - Precision: 0.9377 - Recall: 0.8687 - accuracy: 0.8976 - loss: 0.3781 - val_Precision: 0.8123 - val_Recall: 0.7284 - val_accuracy: 0.7699 - val_loss: 0.8483 - learning_rate: 2.5000e-05

# %%
# Evaluate on train data
train_scores = model.evaluate(train_generator, verbose=0)
print(f"Train Loss: {train_scores[0]:.4f}, Train Accuracy: {train_scores[1]:.4f}, Train Precision: {train_scores[2]:.4f},Train Recall: {train_scores[3]:.4f}")
# Out:
# Train Loss: 0.4073, Train Accuracy: 0.8840, Train Precision: 0.9192,Train Recall: 0.8532

# %%
# Evaluate on test data
test_scores = model.evaluate(test_generator,verbose=0)
print(f"Test Loss: {test_scores[0]:.4f}, Test Accuracy: {test_scores[1]:.4f},Test Precision: {test_scores[2]:.4f},Test Recall: {test_scores[3]:.4f}")
# Out:
# Test Loss: 0.8550, Test Accuracy: 0.7683,Test Precision: 0.8067,Test Recall: 0.7283

# %%
from sklearn.metrics import classification_report, accuracy_score,precision_score, recall_score, f1_score

y_true = test_generator.classes
y_pred_probs = model.predict(test_generator, verbose=1)
y_pred = y_pred_probs.argmax(axis=1)  # Convert probabilities to class indices
# Out:
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 96ms/step

# %%
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))
# Out:
# Classification Report:
#                                       precision    recall  f1-score   support
#
#                       Bacterial_spot       0.91      0.82      0.86       356
#                         Early_blight       0.77      0.80      0.78       310
#                          Late_blight       0.87      0.62      0.72       391
#                            Leaf_Mold       0.89      0.70      0.79       349
#                   Septoria_leaf_spot       0.73      0.67      0.70       363
# Spider_mites Two-spotted_spider_mite       0.62      0.76      0.68       218
#                          Target_Spot       0.78      0.37      0.50       228
#        Tomato_Yellow_Leaf_Curl_Virus       0.83      0.94      0.88       253
#                  Tomato_mosaic_virus       0.94      0.83      0.88       274
#                              healthy       0.57      0.98      0.72       386
#                       powdery_mildew       0.69      0.85      0.76       126
#
#                             accuracy                           0.76      3254
#                            macro avg       0.78      0.76      0.75      3254
#                         weighted avg       0.79      0.76      0.76      3254

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
overall_accuracy = accuracy_score(y_true, y_pred)
overall_precision = precision_score(y_true, y_pred, average='macro')  # Weighted average for class imbalance
overall_recall = recall_score(y_true, y_pred, average='macro')
overall_f1 = f1_score(y_true, y_pred, average='macro')

print(f"Overall Accuracy: {overall_accuracy:.4f}")
print(f"Overall Precision: {overall_precision:.4f}")
print(f"Overall Recall: {overall_recall:.4f}")
print(f"Overall F1-Score: {overall_f1:.4f}")
# Out:
# Overall Accuracy: 0.7603
# Overall Precision: 0.7826
# Overall Recall: 0.7590
# Overall F1-Score: 0.7541

# %%
specificity = []

for i in range(len(cm)):
    tn = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
    fp = cm[:, i].sum() - cm[i, i]
    specificity.append(tn / (tn + fp))

overall_specificity = np.mean(specificity)  # Average specificity

print(f"Overall Specificity: {overall_specificity:.4f}")
# Out:
# Overall Specificity: 0.9758

# %%
# Sensitivity (Recall)
def calculate_specificity(cm, CLASS_NAMES):

    # Specificity
    specificity = []
    for i in range(len(cm)):
        tn = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
        fp = cm[:, i].sum() - cm[i, i]
        specificity.append(tn / (tn + fp))

    print("\nPer-Class Specificity:")
    for idx, class_name in enumerate(CLASS_NAMES):
        print(f"Class {class_name}: {specificity[idx]:.4f}")

    return specificity

# %%
# print("\n--- Train Data Metrics ---")
specificity = calculate_specificity(cm, CLASS_NAMES)
# Out:
# Per-Class Specificity:
# Class Late_blight: 0.9903
# Class Tomato_Yellow_Leaf_Curl_Virus: 0.9752
# Class Septoria_leaf_spot: 0.9874
# Class Early_blight: 0.9893
# Class Spider_mites Two-spotted_spider_mite: 0.9689
# Class powdery_mildew: 0.9671
# Class healthy: 0.9921
# Class Bacterial_spot: 0.9837
# Class Target_Spot: 0.9950
# Class Tomato_mosaic_virus: 0.8999
# Class Leaf_Mold: 0.9850

# %%
class_accuracies = cm.diagonal() / cm.sum(axis=1)

# Create a DataFrame for the class-wise accuracies
class_accuracy_df = pd.DataFrame({
    "Class": list(test_generator.class_indices.keys()),
    "Accuracy": class_accuracies
})

print("\nClass-wise Accuracies:")
print(class_accuracy_df.to_string(index=False))
# Out:
# Class-wise Accuracies:
#                                Class  Accuracy
#                       Bacterial_spot  0.820225
#                         Early_blight  0.796774
#                          Late_blight  0.618926
#                            Leaf_Mold  0.704871
#                   Septoria_leaf_spot  0.672176
# Spider_mites Two-spotted_spider_mite  0.756881
#                          Target_Spot  0.372807
#        Tomato_Yellow_Leaf_Curl_Virus  0.944664
#                  Tomato_mosaic_virus  0.828467
#                              healthy  0.984456
#                       powdery_mildew  0.849206

# %% [markdown]
# ### Run prediction on a sample image

# %%
import random
from tensorflow.keras.preprocessing import image

random_indices = random.sample(range(len(y_true)), 15)

class_names = list(test_generator.class_indices.keys())

# Iterate through the random indices and display actual and predicted results
for idx in random_indices:
    actual_class = class_names[y_true[idx]]
    predicted_class = class_names[y_pred[idx]]
    print(f"Actual: {actual_class} ,  Predicted: {predicted_class}")
# Out:
# Actual: healthy ,  Predicted: healthy
# Actual: Leaf_Mold ,  Predicted: Leaf_Mold
# Actual: Early_blight ,  Predicted: Early_blight
# Actual: Tomato_Yellow_Leaf_Curl_Virus ,  Predicted: Tomato_Yellow_Leaf_Curl_Virus
# Actual: Bacterial_spot ,  Predicted: Bacterial_spot
# Actual: Late_blight ,  Predicted: Late_blight
# Actual: Target_Spot ,  Predicted: Target_Spot
# Actual: healthy ,  Predicted: healthy
# Actual: Leaf_Mold ,  Predicted: Spider_mites Two-spotted_spider_mite
# Actual: Tomato_Yellow_Leaf_Curl_Virus ,  Predicted: Tomato_Yellow_Leaf_Curl_Virus
# Actual: Tomato_Yellow_Leaf_Curl_Virus ,  Predicted: Tomato_Yellow_Leaf_Curl_Virus
# Actual: Septoria_leaf_spot ,  Predicted: Early_blight
# Actual: Early_blight ,  Predicted: Early_blight
# Actual: Target_Spot ,  Predicted: Target_Spot
# Actual: Early_blight ,  Predicted: Early_blight
