# %% [markdown]
# ### Import all the Dependencies

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### Import data into tensorflow dataset object

# %%
# Constants
IMAGE_SIZE = 224  # Replace with your desired image size
BATCH_SIZE = 32
DATASET_DIR = '/kaggle/input/plantvillage/Dataset1'  # Path to your dataset directory
CLASS_NAMES = os.listdir(DATASET_DIR)

# Prepare a list of all image paths and corresponding labels
image_paths = []
labels = []

for class_name in CLASS_NAMES:
    class_dir = os.path.join(DATASET_DIR, class_name)
    for img_name in os.listdir(class_dir):
        image_paths.append(os.path.join(class_dir, img_name))
        labels.append(class_name)

# Create a DataFrame
data = pd.DataFrame({'image_path': image_paths, 'label': labels})

# %%
# Split into train, validation, and test sets
train_data, test_data = train_test_split(data, test_size=0.1, stratify=data['label'], random_state=42)
train_data, val_data = train_test_split(train_data, test_size=0.125, stratify=train_data['label'], random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# Data Augmentation and Data Generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.1,
    height_shift_range=0.1, 
    shear_range=0.2, 
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
)

train_generator = train_datagen.flow_from_dataframe(
    train_data,
    x_col='image_path',
    y_col='label',
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = validation_datagen.flow_from_dataframe(
    val_data,
    x_col='image_path',
    y_col='label',
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_dataframe(
    test_data,
    x_col='image_path',
    y_col='label',
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False  # Important to maintain order for evaluation
)
# Out:
# Found 16252 validated image filenames belonging to 15 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/legacy/preprocessing/image.py:920: UserWarning: Found 1 invalid image filename(s) in x_col="image_path". These filename(s) will be ignored.
#   warnings.warn(
# Found 2322 validated image filenames belonging to 15 classes.
# Found 2064 validated image filenames belonging to 15 classes.

# %%
# Get class indices
class_indices = train_generator.class_indices

# Map class names to their image counts
class_counts_dict = train_data['label'].value_counts().to_dict()

# Create a list of counts in the order of train_generator.class_indices
ordered_counts = [(class_name, class_counts_dict.get(class_name, 0)) for class_name in class_indices.keys()]

# Convert to a DataFrame for better visualization
ordered_counts_df = pd.DataFrame(ordered_counts, columns=['Class Name', 'Image Count'])

# Print the ordered counts
print(ordered_counts_df)
# Out:
#                                      Class Name  Image Count
# 0                 Pepper__bell___Bacterial_spot          785
# 1                        Pepper__bell___healthy         1164
# 2                         Potato___Early_blight          788
# 3                          Potato___Late_blight          787
# 4                              Potato___healthy          120
# 5                         Tomato_Bacterial_spot         1675
# 6                           Tomato_Early_blight          787
# 7                            Tomato_Late_blight         1503
# 8                              Tomato_Leaf_Mold          750
# 9                     Tomato_Septoria_leaf_spot         1395
# 10  Tomato_Spider_mites_Two_spotted_spider_mite         1319
# 11                          Tomato__Target_Spot         1106
# 12        Tomato__Tomato_YellowLeaf__Curl_Virus         2527
# 13                  Tomato__Tomato_mosaic_virus          294
# 14                               Tomato_healthy         1253

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights = dict(enumerate(class_weights))

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=0)
]

# %% [markdown]
# ## Building the Model

# %%
from tensorflow.keras.models import Model
from keras.layers import Flatten, Dense,TimeDistributed,Conv2D,MaxPooling2D,LSTM,Dropout,Reshape,Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2 

strategy=tf.distribute.MirroredStrategy()
with strategy.scope():
    
    model = Sequential()
   
    # Reshaping the image into a sequence
    model.add(Reshape((224, 224 * 3), input_shape=(224, 224, 3)))
    
    # LSTM layers
    # model.add(LSTM(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3))
    model.add(LSTM(64, return_sequences=True, dropout=0.3, recurrent_dropout=0.3))
    model.add(LSTM(32, return_sequences=False, dropout=0.3, recurrent_dropout=0.3))
    
    # Dense Layers for Classification
    model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dense(15, activation='softmax'))

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy','Precision','Recall'])
print(model.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ reshape (Reshape)                    │ (None, 224, 672)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 224, 64)             │         188,672 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │           4,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 15)                  │           1,935 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 207,247 (809.56 KB)
#  Trainable params: 207,247 (809.56 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
history = model.fit(
    train_generator,
    batch_size=BATCH_SIZE ,
    # steps_per_epoch = steps_per_epoch,  # Total samples / batch_size
    validation_data=validation_generator,
    # validation_steps = validation_steps,
    epochs=30,
    callbacks = callbacks
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 445s 852ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.1255 - loss: 2.6839 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.1628 - val_loss: 2.6095 - learning_rate: 1.0000e-04
# Epoch 2/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 434s 848ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.1574 - loss: 2.6072 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.1507 - val_loss: 2.6025 - learning_rate: 1.0000e-04
# Epoch 3/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 432s 845ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.1503 - loss: 2.5930 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.1585 - val_loss: 2.5345 - learning_rate: 1.0000e-04
# Epoch 4/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 432s 845ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.1660 - loss: 2.5534 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.1921 - val_loss: 2.4939 - learning_rate: 1.0000e-04
# Epoch 5/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 434s 849ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.1752 - loss: 2.5195 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.2162 - val_loss: 2.3708 - learning_rate: 1.0000e-04
# Epoch 6/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 431s 844ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.2010 - loss: 2.4741 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.2748 - val_loss: 2.2972 - learning_rate: 1.0000e-04
# Epoch 7/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 434s 848ms/step - Precision: 0.6465 - Recall: 0.0042 - accuracy: 0.2252 - loss: 2.4176 - val_Precision: 0.8750 - val_Recall: 0.0543 - val_accuracy: 0.2946 - val_loss: 2.2354 - learning_rate: 1.0000e-04
# Epoch 8/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 433s 848ms/step - Precision: 0.5914 - Recall: 0.0254 - accuracy: 0.2360 - loss: 2.3748 - val_Precision: 0.7518 - val_Recall: 0.0913 - val_accuracy: 0.2911 - val_loss: 2.1826 - learning_rate: 1.0000e-04
# Epoch 9/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 433s 847ms/step - Precision: 0.6546 - Recall: 0.0528 - accuracy: 0.2469 - loss: 2.3439 - val_Precision: 0.6504 - val_Recall: 0.1378 - val_accuracy: 0.3127 - val_loss: 2.1423 - learning_rate: 1.0000e-04
# Epoch 10/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 434s 850ms/step - Precision: 0.6523 - Recall: 0.0618 - accuracy: 0.2565 - loss: 2.3088 - val_Precision: 0.7243 - val_Recall: 0.1154 - val_accuracy: 0.3480 - val_loss: 2.0965 - learning_rate: 1.0000e-04
# Epoch 11/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 431s 843ms/step - Precision: 0.6943 - Recall: 0.0737 - accuracy: 0.2699 - loss: 2.2675 - val_Precision: 0.7796 - val_Recall: 0.1249 - val_accuracy: 0.3678 - val_loss: 2.0175 - learning_rate: 1.0000e-04
# Epoch 12/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 440s 861ms/step - Precision: 0.7101 - Recall: 0.0814 - accuracy: 0.2890 - loss: 2.2258 - val_Precision: 0.7639 - val_Recall: 0.1533 - val_accuracy: 0.4126 - val_loss: 1.9955 - learning_rate: 1.0000e-04
# Epoch 13/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 435s 850ms/step - Precision: 0.6795 - Recall: 0.0833 - accuracy: 0.2952 - loss: 2.2057 - val_Precision: 0.7546 - val_Recall: 0.1774 - val_accuracy: 0.4152 - val_loss: 1.9258 - learning_rate: 1.0000e-04
# Epoch 14/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 433s 846ms/step - Precision: 0.7051 - Recall: 0.0953 - accuracy: 0.3070 - loss: 2.1697 - val_Precision: 0.7678 - val_Recall: 0.1766 - val_accuracy: 0.4117 - val_loss: 1.8990 - learning_rate: 1.0000e-04
# Epoch 15/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 433s 848ms/step - Precision: 0.6893 - Recall: 0.0905 - accuracy: 0.3039 - loss: 2.1735 - val_Precision: 0.7418 - val_Recall: 0.1757 - val_accuracy: 0.4040 - val_loss: 1.9458 - learning_rate: 1.0000e-04
# Epoch 16/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 438s 856ms/step - Precision: 0.7031 - Recall: 0.1043 - accuracy: 0.3205 - loss: 2.1370 - val_Precision: 0.8230 - val_Recall: 0.1723 - val_accuracy: 0.4479 - val_loss: 1.8488 - learning_rate: 1.0000e-04
# Epoch 17/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 436s 853ms/step - Precision: 0.7084 - Recall: 0.1035 - accuracy: 0.3267 - loss: 2.1179 - val_Precision: 0.7803 - val_Recall: 0.1774 - val_accuracy: 0.4367 - val_loss: 1.8326 - learning_rate: 1.0000e-04
# Epoch 18/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 435s 850ms/step - Precision: 0.6986 - Recall: 0.1087 - accuracy: 0.3348 - loss: 2.1002 - val_Precision: 0.7358 - val_Recall: 0.2016 - val_accuracy: 0.4393 - val_loss: 1.8163 - learning_rate: 1.0000e-04
# Epoch 19/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 433s 847ms/step - Precision: 0.6868 - Recall: 0.1133 - accuracy: 0.3369 - loss: 2.0853 - val_Precision: 0.7152 - val_Recall: 0.1904 - val_accuracy: 0.4229 - val_loss: 1.8215 - learning_rate: 1.0000e-04
# Epoch 20/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 434s 850ms/step - Precision: 0.6959 - Recall: 0.1169 - accuracy: 0.3471 - loss: 2.0596 - val_Precision: 0.7492 - val_Recall: 0.2059 - val_accuracy: 0.4496 - val_loss: 1.7879 - learning_rate: 1.0000e-04
# Epoch 21/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 433s 846ms/step - Precision: 0.6885 - Recall: 0.1267 - accuracy: 0.3554 - loss: 2.0282 - val_Precision: 0.7697 - val_Recall: 0.2188 - val_accuracy: 0.4574 - val_loss: 1.7531 - learning_rate: 1.0000e-04
# Epoch 22/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 432s 845ms/step - Precision: 0.7015 - Recall: 0.1304 - accuracy: 0.3504 - loss: 2.0439 - val_Precision: 0.7937 - val_Recall: 0.2188 - val_accuracy: 0.4686 - val_loss: 1.7163 - learning_rate: 1.0000e-04
# Epoch 23/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 433s 846ms/step - Precision: 0.6971 - Recall: 0.1403 - accuracy: 0.3682 - loss: 2.0004 - val_Precision: 0.8411 - val_Recall: 0.2326 - val_accuracy: 0.5022 - val_loss: 1.6418 - learning_rate: 1.0000e-04
# Epoch 24/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 441s 862ms/step - Precision: 0.6854 - Recall: 0.1351 - accuracy: 0.3692 - loss: 2.0007 - val_Precision: 0.7748 - val_Recall: 0.2489 - val_accuracy: 0.4720 - val_loss: 1.7019 - learning_rate: 1.0000e-04
# Epoch 25/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 436s 852ms/step - Precision: 0.6965 - Recall: 0.1395 - accuracy: 0.3763 - loss: 1.9872 - val_Precision: 0.7314 - val_Recall: 0.2369 - val_accuracy: 0.4694 - val_loss: 1.6979 - learning_rate: 1.0000e-04
# Epoch 26/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 435s 851ms/step - Precision: 0.7055 - Recall: 0.1555 - accuracy: 0.3787 - loss: 1.9571 - val_Precision: 0.8152 - val_Recall: 0.2317 - val_accuracy: 0.5056 - val_loss: 1.6480 - learning_rate: 1.0000e-04
# Epoch 27/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 433s 847ms/step - Precision: 0.7219 - Recall: 0.1538 - accuracy: 0.3850 - loss: 1.9429 - val_Precision: 0.7468 - val_Recall: 0.2515 - val_accuracy: 0.5004 - val_loss: 1.6133 - learning_rate: 1.0000e-04
# Epoch 28/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 433s 848ms/step - Precision: 0.6974 - Recall: 0.1520 - accuracy: 0.3779 - loss: 1.9444 - val_Precision: 0.7875 - val_Recall: 0.2713 - val_accuracy: 0.5116 - val_loss: 1.5737 - learning_rate: 1.0000e-04
# Epoch 29/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 438s 856ms/step - Precision: 0.6923 - Recall: 0.1608 - accuracy: 0.3936 - loss: 1.9145 - val_Precision: 0.8165 - val_Recall: 0.2722 - val_accuracy: 0.5211 - val_loss: 1.5764 - learning_rate: 1.0000e-04
# Epoch 30/30
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 436s 853ms/step - Precision: 0.6962 - Recall: 0.1654 - accuracy: 0.3982 - loss: 1.9002 - val_Precision: 0.7970 - val_Recall: 0.2705 - val_accuracy: 0.5220 - val_loss: 1.6011 - learning_rate: 1.0000e-04

# %%
# Evaluate on train data
train_scores = model.evaluate(train_generator, verbose=0)
print(f"Train Loss: {train_scores[0]:.4f}, Train Accuracy: {train_scores[1]:.4f}, Train Precision: {train_scores[2]:.4f},Train Recall: {train_scores[3]:.4f}")
# Out:
# Train Loss: 1.6681, Train Accuracy: 0.4909, Train Precision: 0.7575,Train Recall: 0.2291

# %%
# Evaluate on test data
test_scores = model.evaluate(test_generator,verbose=0)
print(f"Test Loss: {test_scores[0]:.4f}, Test Accuracy: {test_scores[1]:.4f},Test Precision: {test_scores[2]:.4f},Test Recall: {test_scores[3]:.4f}")
# Out:
# Test Loss: 1.5579, Test Accuracy: 0.5116,Test Precision: 0.8029,Test Recall: 0.2645

# %%
from sklearn.metrics import classification_report, accuracy_score,precision_score, recall_score, f1_score

y_true = test_generator.classes
y_pred_probs = model.predict(test_generator, verbose=1)
y_pred = y_pred_probs.argmax(axis=1)  # Convert probabilities to class indices
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 17s 245ms/step

# %%
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))
# Out:
# Classification Report:
#                                              precision    recall  f1-score   support
#
#               Pepper__bell___Bacterial_spot       0.26      0.10      0.14       100
#                      Pepper__bell___healthy       0.40      0.72      0.52       148
#                       Potato___Early_blight       0.50      0.82      0.62       100
#                        Potato___Late_blight       0.00      0.00      0.00       100
#                            Potato___healthy       0.00      0.00      0.00        15
#                       Tomato_Bacterial_spot       0.58      0.72      0.64       213
#                         Tomato_Early_blight       0.00      0.00      0.00       100
#                          Tomato_Late_blight       0.80      0.25      0.38       191
#                            Tomato_Leaf_Mold       0.66      0.22      0.33        95
#                   Tomato_Septoria_leaf_spot       0.48      0.46      0.47       177
# Tomato_Spider_mites_Two_spotted_spider_mite       0.43      0.52      0.47       168
#                         Tomato__Target_Spot       0.35      0.53      0.42       140
#       Tomato__Tomato_YellowLeaf__Curl_Virus       0.65      0.90      0.75       321
#                 Tomato__Tomato_mosaic_virus       1.00      0.03      0.05        37
#                              Tomato_healthy       0.59      0.77      0.67       159
#
#                                    accuracy                           0.52      2064
#                                   macro avg       0.45      0.40      0.36      2064
#                                weighted avg       0.49      0.52      0.47      2064
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
overall_accuracy = accuracy_score(y_true, y_pred)
overall_precision = precision_score(y_true, y_pred, average='macro')  # Weighted average for class imbalance
overall_recall = recall_score(y_true, y_pred, average='macro')
overall_f1 = f1_score(y_true, y_pred, average='macro')

print(f"Overall Accuracy: {overall_accuracy:.4f}")
print(f"Overall Precision: {overall_precision:.4f}")
print(f"Overall Recall: {overall_recall:.4f}")
print(f"Overall F1-Score: {overall_f1:.4f}")
# Out:
# Overall Accuracy: 0.5213
# Overall Precision: 0.4465
# Overall Recall: 0.4025
# Overall F1-Score: 0.3647
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
specificity = []

for i in range(len(cm)):
    tn = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
    fp = cm[:, i].sum() - cm[i, i]
    specificity.append(tn / (tn + fp))

overall_specificity = np.mean(specificity)  # Average specificity

print(f"Overall Specificity: {overall_specificity:.4f}")
# Out:
# Overall Specificity: 0.9650

# %%
# Sensitivity (Recall)
def calculate_specificity(cm, CLASS_NAMES):

    # Specificity
    specificity = []
    for i in range(len(cm)):
        tn = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
        fp = cm[:, i].sum() - cm[i, i]
        specificity.append(tn / (tn + fp))

    print("\nPer-Class Specificity:")
    for idx, class_name in enumerate(CLASS_NAMES):
        print(f"Class {class_name}: {specificity[idx]:.4f}")

    return specificity

# %%
# print("\n--- Train Data Metrics ---")
specificity = calculate_specificity(cm, CLASS_NAMES)
# Out:
# Per-Class Specificity:
# Class Pepper__bell___Bacterial_spot: 0.9857
# Class Potato___healthy: 0.9181
# Class Tomato_Leaf_Mold: 0.9588
# Class Tomato__Tomato_YellowLeaf__Curl_Virus: 0.9995
# Class Tomato_Bacterial_spot: 1.0000
# Class Tomato_Septoria_leaf_spot: 0.9395
# Class Tomato_healthy: 0.9995
# Class Tomato_Spider_mites_Two_spotted_spider_mite: 0.9936
# Class Tomato_Early_blight: 0.9944
# Class Tomato__Target_Spot: 0.9534
# Class Pepper__bell___healthy: 0.9378
# Class Potato___Late_blight: 0.9283
# Class Tomato_Late_blight: 0.9105
# Class Potato___Early_blight: 1.0000
# Class Tomato__Tomato_mosaic_virus: 0.9554

# %%
class_accuracies = cm.diagonal() / cm.sum(axis=1)

# Create a DataFrame for the class-wise accuracies
class_accuracy_df = pd.DataFrame({
    "Class": list(test_generator.class_indices.keys()),
    "Accuracy": class_accuracies
})

print("\nClass-wise Accuracies:")
print(class_accuracy_df.to_string(index=False))
# Out:
# Class-wise Accuracies:
#                                       Class  Accuracy
#               Pepper__bell___Bacterial_spot  0.100000
#                      Pepper__bell___healthy  0.716216
#                       Potato___Early_blight  0.820000
#                        Potato___Late_blight  0.000000
#                            Potato___healthy  0.000000
#                       Tomato_Bacterial_spot  0.723005
#                         Tomato_Early_blight  0.000000
#                          Tomato_Late_blight  0.246073
#                            Tomato_Leaf_Mold  0.221053
#                   Tomato_Septoria_leaf_spot  0.457627
# Tomato_Spider_mites_Two_spotted_spider_mite  0.523810
#                         Tomato__Target_Spot  0.528571
#       Tomato__Tomato_YellowLeaf__Curl_Virus  0.900312
#                 Tomato__Tomato_mosaic_virus  0.027027
#                              Tomato_healthy  0.773585

# %% [markdown]
# ### Run prediction on a sample image

# %%
import random
from tensorflow.keras.preprocessing import image

random_indices = random.sample(range(len(y_true)), 15)

class_names = list(test_generator.class_indices.keys())

# Iterate through the random indices and display actual and predicted results
for idx in random_indices:
    actual_class = class_names[y_true[idx]]
    predicted_class = class_names[y_pred[idx]]
    print(f"Actual: {actual_class} ,  Predicted: {predicted_class}")
# Out:
# Actual: Tomato_Bacterial_spot ,  Predicted: Tomato__Tomato_YellowLeaf__Curl_Virus
# Actual: Tomato_Bacterial_spot ,  Predicted: Tomato_Bacterial_spot
# Actual: Tomato_Bacterial_spot ,  Predicted: Tomato_Bacterial_spot
# Actual: Tomato_healthy ,  Predicted: Tomato_healthy
# Actual: Tomato_Bacterial_spot ,  Predicted: Tomato_Late_blight
# Actual: Tomato_Late_blight ,  Predicted: Tomato_Late_blight
# Actual: Tomato__Tomato_YellowLeaf__Curl_Virus ,  Predicted: Tomato__Tomato_YellowLeaf__Curl_Virus
# Actual: Tomato_Late_blight ,  Predicted: Tomato_healthy
# Actual: Tomato_Septoria_leaf_spot ,  Predicted: Tomato_Septoria_leaf_spot
# Actual: Potato___Late_blight ,  Predicted: Tomato__Target_Spot
# Actual: Potato___Late_blight ,  Predicted: Tomato_Bacterial_spot
# Actual: Pepper__bell___Bacterial_spot ,  Predicted: Tomato__Tomato_YellowLeaf__Curl_Virus
# Actual: Pepper__bell___Bacterial_spot ,  Predicted: Pepper__bell___healthy
# Actual: Tomato_Bacterial_spot ,  Predicted: Tomato_Bacterial_spot
# Actual: Potato___Late_blight ,  Predicted: Tomato_Spider_mites_Two_spotted_spider_mite
