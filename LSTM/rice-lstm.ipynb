# %% [markdown]
# ### Import all the Dependencies

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### Import data into tensorflow dataset object

# %%
# Constants
IMAGE_SIZE = 224  # Replace with your desired image size
BATCH_SIZE = 32
DATASET_DIR = '/kaggle/input/riceleaf/Dataset4'  # Path to your dataset directory
CLASS_NAMES = os.listdir(DATASET_DIR)

# Prepare a list of all image paths and corresponding labels
image_paths = []
labels = []

for class_name in CLASS_NAMES:
    class_dir = os.path.join(DATASET_DIR, class_name)
    for img_name in os.listdir(class_dir):
        image_paths.append(os.path.join(class_dir, img_name))
        labels.append(class_name)

# Create a DataFrame
data = pd.DataFrame({'image_path': image_paths, 'label': labels})

# %%
# Split into train, validation, and test sets
train_data, test_data = train_test_split(data, test_size=0.1, stratify=data['label'], random_state=42)
train_data, val_data = train_test_split(train_data, test_size=0.125, stratify=train_data['label'], random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# def sequence_data_generator(generator, sequence_length):
#     while True:
#         images, labels = next(generator)
#         batch_size = images.shape[0]
#         # Reshape to create sequences (assuming batch_size is divisible by sequence_length)
#         sequences = images.reshape(batch_size // sequence_length, sequence_length, 224, 224, 3)
#         yield sequences, labels[:batch_size // sequence_length]

# %%
# Data Augmentation and Data Generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.1,
    height_shift_range=0.1, 
    shear_range=0.2, 
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
)

train_generator = train_datagen.flow_from_dataframe(
    train_data,
    x_col='image_path',
    y_col='label',
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = validation_datagen.flow_from_dataframe(
    val_data,
    x_col='image_path',
    y_col='label',
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_dataframe(
    test_data,
    x_col='image_path',
    y_col='label',
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False  # Important to maintain order for evaluation
)
# Out:
# Found 4670 validated image filenames belonging to 4 classes.
# Found 668 validated image filenames belonging to 4 classes.
# Found 594 validated image filenames belonging to 4 classes.

# %%
# SEQUENCE_LENGTH = 4
# train_generator = sequence_data_generator(train_generator, SEQUENCE_LENGTH)
# validation_generator = sequence_data_generator(validation_generator, SEQUENCE_LENGTH)
# test_generator = sequence_data_generator(test_generator, SEQUENCE_LENGTH)

# %%
# steps_per_epoch = len(train_generator)
# validation_steps = len(validation_generator)
# test_steps = len(test_generator)

# print(steps_per_epoch)
# print(validation_steps)
# print(test_steps)

# total_samples = test_steps * BATCH_SIZE

# %%
# Get class indices
class_indices = train_generator.class_indices

# Map class names to their image counts
class_counts_dict = train_data['label'].value_counts().to_dict()

# Create a list of counts in the order of train_generator.class_indices
ordered_counts = [(class_name, class_counts_dict.get(class_name, 0)) for class_name in class_indices.keys()]

# Convert to a DataFrame for better visualization
ordered_counts_df = pd.DataFrame(ordered_counts, columns=['Class Name', 'Image Count'])

# Print the ordered counts
print(ordered_counts_df)
# Out:
#         Class Name  Image Count
# 0  Bacterialblight         1246
# 1            Blast         1134
# 2        Brownspot         1260
# 3           Tungro         1030

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights = dict(enumerate(class_weights))

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=0)
]

# %% [markdown]
# ## Building the Model

# %%
from tensorflow.keras.models import Model
from keras.layers import Flatten, Dense,TimeDistributed,Conv2D,MaxPooling2D,LSTM,Dropout,Reshape,Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2 

strategy=tf.distribute.MirroredStrategy()
with strategy.scope():
    
    model = Sequential()
   
    # Reshaping the image into a sequence
    model.add(Reshape((224, 224 * 3), input_shape=(224, 224, 3)))
    
    # LSTM layers
    # model.add(LSTM(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3))
    model.add(LSTM(64, return_sequences=True, dropout=0.3, recurrent_dropout=0.3))
    model.add(LSTM(32, return_sequences=False, dropout=0.3, recurrent_dropout=0.3))
    
    # Dense Layers for Classification
    model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dense(4, activation='softmax'))

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy','Precision','Recall'])
print(model.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ reshape (Reshape)                    │ (None, 224, 672)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 224, 64)             │         188,672 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │           4,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │             516 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 205,828 (804.02 KB)
#  Trainable params: 205,828 (804.02 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# from PIL import ImageFile
# ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
history = model.fit(
    train_generator,
    batch_size=BATCH_SIZE ,
    # steps_per_epoch = steps_per_epoch,  # Total samples / batch_size
    validation_data=validation_generator,
    # validation_steps = validation_steps,
    epochs=30,
    callbacks = callbacks
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 136s 851ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.2627 - loss: 1.4348 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.3263 - val_loss: 1.4091 - learning_rate: 1.0000e-04
# Epoch 2/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 838ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.3101 - loss: 1.4177 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4371 - val_loss: 1.3680 - learning_rate: 1.0000e-04
# Epoch 3/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 124s 832ms/step - Precision: 0.0000e+00 - Recall: 0.0000e+00 - accuracy: 0.3162 - loss: 1.4021 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4162 - val_loss: 1.3450 - learning_rate: 1.0000e-04
# Epoch 4/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 834ms/step - Precision: 0.0646 - Recall: 6.4415e-05 - accuracy: 0.3636 - loss: 1.3631 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_accuracy: 0.4311 - val_loss: 1.3328 - learning_rate: 1.0000e-04
# Epoch 5/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 126s 843ms/step - Precision: 0.4996 - Recall: 0.0043 - accuracy: 0.3738 - loss: 1.3402 - val_Precision: 0.8571 - val_Recall: 0.0180 - val_accuracy: 0.5509 - val_loss: 1.2804 - learning_rate: 1.0000e-04
# Epoch 6/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 127s 847ms/step - Precision: 0.5462 - Recall: 0.0329 - accuracy: 0.4114 - loss: 1.3101 - val_Precision: 0.7458 - val_Recall: 0.1317 - val_accuracy: 0.5060 - val_loss: 1.2324 - learning_rate: 1.0000e-04
# Epoch 7/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 837ms/step - Precision: 0.5941 - Recall: 0.0856 - accuracy: 0.4507 - loss: 1.2615 - val_Precision: 0.8182 - val_Recall: 0.2156 - val_accuracy: 0.5449 - val_loss: 1.1559 - learning_rate: 1.0000e-04
# Epoch 8/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 840ms/step - Precision: 0.6275 - Recall: 0.1428 - accuracy: 0.4660 - loss: 1.2430 - val_Precision: 0.7979 - val_Recall: 0.2246 - val_accuracy: 0.5359 - val_loss: 1.1333 - learning_rate: 1.0000e-04
# Epoch 9/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 834ms/step - Precision: 0.5966 - Recall: 0.1681 - accuracy: 0.4638 - loss: 1.2213 - val_Precision: 0.6783 - val_Recall: 0.2335 - val_accuracy: 0.5150 - val_loss: 1.1230 - learning_rate: 1.0000e-04
# Epoch 10/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 124s 831ms/step - Precision: 0.6325 - Recall: 0.2072 - accuracy: 0.4955 - loss: 1.1803 - val_Precision: 0.6714 - val_Recall: 0.2814 - val_accuracy: 0.5389 - val_loss: 1.0861 - learning_rate: 1.0000e-04
# Epoch 11/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 836ms/step - Precision: 0.6694 - Recall: 0.2175 - accuracy: 0.5023 - loss: 1.1659 - val_Precision: 0.6891 - val_Recall: 0.3982 - val_accuracy: 0.5479 - val_loss: 1.0859 - learning_rate: 1.0000e-04
# Epoch 12/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 124s 830ms/step - Precision: 0.6654 - Recall: 0.2588 - accuracy: 0.5182 - loss: 1.1458 - val_Precision: 0.6667 - val_Recall: 0.4072 - val_accuracy: 0.5329 - val_loss: 1.0703 - learning_rate: 1.0000e-04
# Epoch 13/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 833ms/step - Precision: 0.6643 - Recall: 0.2757 - accuracy: 0.5329 - loss: 1.1269 - val_Precision: 0.6476 - val_Recall: 0.4401 - val_accuracy: 0.5539 - val_loss: 1.0733 - learning_rate: 1.0000e-04
# Epoch 14/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 124s 831ms/step - Precision: 0.6584 - Recall: 0.3122 - accuracy: 0.5343 - loss: 1.1242 - val_Precision: 0.6753 - val_Recall: 0.4671 - val_accuracy: 0.5898 - val_loss: 1.0065 - learning_rate: 1.0000e-04
# Epoch 15/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 833ms/step - Precision: 0.6808 - Recall: 0.3191 - accuracy: 0.5525 - loss: 1.0921 - val_Precision: 0.7195 - val_Recall: 0.5299 - val_accuracy: 0.6347 - val_loss: 0.9395 - learning_rate: 1.0000e-04
# Epoch 16/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 124s 830ms/step - Precision: 0.6657 - Recall: 0.3360 - accuracy: 0.5453 - loss: 1.1066 - val_Precision: 0.6776 - val_Recall: 0.4970 - val_accuracy: 0.6138 - val_loss: 0.9886 - learning_rate: 1.0000e-04
# Epoch 17/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 124s 828ms/step - Precision: 0.6805 - Recall: 0.3566 - accuracy: 0.5711 - loss: 1.0797 - val_Precision: 0.6914 - val_Recall: 0.5299 - val_accuracy: 0.6317 - val_loss: 0.9418 - learning_rate: 1.0000e-04
# Epoch 18/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 124s 831ms/step - Precision: 0.6721 - Recall: 0.3822 - accuracy: 0.5712 - loss: 1.0689 - val_Precision: 0.6957 - val_Recall: 0.5269 - val_accuracy: 0.6108 - val_loss: 0.9555 - learning_rate: 1.0000e-04
# Epoch 19/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 124s 830ms/step - Precision: 0.6853 - Recall: 0.4088 - accuracy: 0.5788 - loss: 1.0555 - val_Precision: 0.6794 - val_Recall: 0.5329 - val_accuracy: 0.6317 - val_loss: 0.9740 - learning_rate: 1.0000e-04
# Epoch 20/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 126s 843ms/step - Precision: 0.6795 - Recall: 0.4216 - accuracy: 0.5961 - loss: 1.0330 - val_Precision: 0.7113 - val_Recall: 0.6048 - val_accuracy: 0.6467 - val_loss: 0.8901 - learning_rate: 1.0000e-04
# Epoch 21/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 836ms/step - Precision: 0.6921 - Recall: 0.4536 - accuracy: 0.5985 - loss: 1.0180 - val_Precision: 0.6975 - val_Recall: 0.5868 - val_accuracy: 0.6437 - val_loss: 0.9340 - learning_rate: 1.0000e-04
# Epoch 22/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 834ms/step - Precision: 0.6976 - Recall: 0.4532 - accuracy: 0.5983 - loss: 1.0221 - val_Precision: 0.7118 - val_Recall: 0.6138 - val_accuracy: 0.6677 - val_loss: 0.8842 - learning_rate: 1.0000e-04
# Epoch 23/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 124s 829ms/step - Precision: 0.7047 - Recall: 0.4769 - accuracy: 0.6132 - loss: 0.9931 - val_Precision: 0.6542 - val_Recall: 0.5778 - val_accuracy: 0.6138 - val_loss: 0.9882 - learning_rate: 1.0000e-04
# Epoch 24/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 833ms/step - Precision: 0.6865 - Recall: 0.4700 - accuracy: 0.6044 - loss: 1.0122 - val_Precision: 0.6976 - val_Recall: 0.6078 - val_accuracy: 0.6557 - val_loss: 0.9196 - learning_rate: 1.0000e-04
# Epoch 25/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 833ms/step - Precision: 0.6895 - Recall: 0.4852 - accuracy: 0.6102 - loss: 0.9986 - val_Precision: 0.6969 - val_Recall: 0.5988 - val_accuracy: 0.6707 - val_loss: 0.8906 - learning_rate: 1.0000e-04
# Epoch 26/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 840ms/step - Precision: 0.6991 - Recall: 0.5132 - accuracy: 0.6271 - loss: 0.9577 - val_Precision: 0.7057 - val_Recall: 0.6317 - val_accuracy: 0.6707 - val_loss: 0.8741 - learning_rate: 1.0000e-04
# Epoch 27/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 124s 832ms/step - Precision: 0.6903 - Recall: 0.5079 - accuracy: 0.6207 - loss: 0.9749 - val_Precision: 0.6847 - val_Recall: 0.6048 - val_accuracy: 0.6557 - val_loss: 0.8872 - learning_rate: 1.0000e-04
# Epoch 28/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 835ms/step - Precision: 0.7036 - Recall: 0.5143 - accuracy: 0.6390 - loss: 0.9508 - val_Precision: 0.7196 - val_Recall: 0.6377 - val_accuracy: 0.6826 - val_loss: 0.8454 - learning_rate: 1.0000e-04
# Epoch 29/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 838ms/step - Precision: 0.6957 - Recall: 0.5143 - accuracy: 0.6315 - loss: 0.9634 - val_Precision: 0.6949 - val_Recall: 0.6138 - val_accuracy: 0.6617 - val_loss: 0.8866 - learning_rate: 1.0000e-04
# Epoch 30/30
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 125s 835ms/step - Precision: 0.7123 - Recall: 0.5251 - accuracy: 0.6412 - loss: 0.9375 - val_Precision: 0.7061 - val_Recall: 0.6257 - val_accuracy: 0.6617 - val_loss: 0.8310 - learning_rate: 1.0000e-04

# %%
# Evaluate on train data
train_scores = model.evaluate(train_generator, verbose=0)
print(f"Train Loss: {train_scores[0]:.4f}, Train Accuracy: {train_scores[1]:.4f}, Train Precision: {train_scores[2]:.4f},Train Recall: {train_scores[3]:.4f}")
# Out:
# Train Loss: 0.8306, Train Accuracy: 0.6792, Train Precision: 0.7176,Train Recall: 0.6334

# %%
# Evaluate on test data
test_scores = model.evaluate(test_generator,verbose=0)
print(f"Test Loss: {test_scores[0]:.4f}, Test Accuracy: {test_scores[1]:.4f},Test Precision: {test_scores[2]:.4f},Test Recall: {test_scores[3]:.4f}")
# Out:
# Test Loss: 0.6644, Test Accuracy: 0.7677,Test Precision: 0.7978,Test Recall: 0.7172

# %%
from sklearn.metrics import classification_report, accuracy_score,precision_score, recall_score, f1_score

y_true = test_generator.classes
y_pred_probs = model.predict(test_generator, verbose=1)
y_pred = y_pred_probs.argmax(axis=1)  # Convert probabilities to class indices
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step

# %%
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))
# Out:
# Classification Report:
#                  precision    recall  f1-score   support
#
# Bacterialblight       0.73      0.70      0.71       159
#           Blast       0.66      0.43      0.52       144
#       Brownspot       0.85      0.88      0.87       160
#          Tungro       0.65      0.90      0.75       131
#
#        accuracy                           0.73       594
#       macro avg       0.72      0.73      0.71       594
#    weighted avg       0.73      0.73      0.72       594

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
overall_accuracy = accuracy_score(y_true, y_pred)
overall_precision = precision_score(y_true, y_pred, average='macro')  # Weighted average for class imbalance
overall_recall = recall_score(y_true, y_pred, average='macro')
overall_f1 = f1_score(y_true, y_pred, average='macro')

print(f"Overall Accuracy: {overall_accuracy:.4f}")
print(f"Overall Precision: {overall_precision:.4f}")
print(f"Overall Recall: {overall_recall:.4f}")
print(f"Overall F1-Score: {overall_f1:.4f}")
# Out:
# Overall Accuracy: 0.7273
# Overall Precision: 0.7220
# Overall Recall: 0.7277
# Overall F1-Score: 0.7136

# %%
specificity = []

for i in range(len(cm)):
    tn = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
    fp = cm[:, i].sum() - cm[i, i]
    specificity.append(tn / (tn + fp))

overall_specificity = np.mean(specificity)  # Average specificity

print(f"Overall Specificity: {overall_specificity:.4f}")
# Out:
# Overall Specificity: 0.9097

# %%
# Sensitivity (Recall)
def calculate_specificity(cm, CLASS_NAMES):

    # Specificity
    specificity = []
    for i in range(len(cm)):
        tn = cm.sum() - (cm[i, :].sum() + cm[:, i].sum() - cm[i, i])
        fp = cm[:, i].sum() - cm[i, i]
        specificity.append(tn / (tn + fp))

    print("\nPer-Class Specificity:")
    for idx, class_name in enumerate(CLASS_NAMES):
        print(f"Class {class_name}: {specificity[idx]:.4f}")

    return specificity

# %%
# print("\n--- Train Data Metrics ---")
specificity = calculate_specificity(cm, CLASS_NAMES)
# Out:
# Per-Class Specificity:
# Class Tungro: 0.9034
# Class Bacterialblight: 0.9289
# Class Blast: 0.9447
# Class Brownspot: 0.8618

# %%
class_accuracies = cm.diagonal() / cm.sum(axis=1)

# Create a DataFrame for the class-wise accuracies
class_accuracy_df = pd.DataFrame({
    "Class": list(test_generator.class_indices.keys()),
    "Accuracy": class_accuracies
})

print("\nClass-wise Accuracies:")
print(class_accuracy_df.to_string(index=False))
# Out:
# Class-wise Accuracies:
#           Class  Accuracy
# Bacterialblight  0.698113
#           Blast  0.430556
#       Brownspot  0.881250
#          Tungro  0.900763

# %% [markdown]
# ### Run prediction on a sample image

# %%
import random
from tensorflow.keras.preprocessing import image

random_indices = random.sample(range(len(y_true)), 15)

class_names = list(test_generator.class_indices.keys())

# Iterate through the random indices and display actual and predicted results
for idx in random_indices:
    actual_class = class_names[y_true[idx]]
    predicted_class = class_names[y_pred[idx]]
    print(f"Actual: {actual_class} ,  Predicted: {predicted_class}")
# Out:
# Actual: Bacterialblight ,  Predicted: Bacterialblight
# Actual: Blast ,  Predicted: Tungro
# Actual: Blast ,  Predicted: Blast
# Actual: Brownspot ,  Predicted: Blast
# Actual: Blast ,  Predicted: Tungro
# Actual: Bacterialblight ,  Predicted: Bacterialblight
# Actual: Brownspot ,  Predicted: Brownspot
# Actual: Tungro ,  Predicted: Tungro
# Actual: Blast ,  Predicted: Bacterialblight
# Actual: Brownspot ,  Predicted: Brownspot
# Actual: Bacterialblight ,  Predicted: Blast
# Actual: Tungro ,  Predicted: Tungro
# Actual: Blast ,  Predicted: Blast
# Actual: Bacterialblight ,  Predicted: Bacterialblight
# Actual: Bacterialblight ,  Predicted: Bacterialblight
